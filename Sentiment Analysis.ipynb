# %% [markdown]
# # Import Data

# %%
#import main libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from datetime import datetime
import warnings

# %%
import pandas as pd

# Provide the full path to your file
file_path = r"C:\Users\JASH PRAJAPATI\Desktop\My Projecta\Hackathon\Social Media Engagement Report_with_sentiment_vader.xlsx"

# Read the Excel file
df = pd.read_excel(file_path)

# Display the first few rows
print(df.head())
# Out:
#     Platform                               Post ID Post Type  \
# 0  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 1   Facebook  a30c948b-0fb3-4e92-95da-e2dea184f568      Link
# 2    Twitter  aee74d06-c775-459c-8fc4-013ce25644f1     Image
# 3  Instagram  80415748-a509-4fc6-8b55-74f2babe5dac     Image
# 4   LinkedIn  14d34185-639a-4508-a8b6-02a743fe0dbc      Link
#
#                             Post Review          Post Timestamp       Date  \
# 0    Loved the creativity in this post. 2023-07-30 06:40:06.356 2023-07-30
# 1  Engaging and informative, well done! 2022-06-19 14:15:59.833 2022-06-19
# 2            Just another regular post. 2022-06-04 06:19:50.403 2022-06-04
# 3  Not up to the mark, could be better. 2022-05-12 15:41:21.902 2022-05-12
# 4    Not appropriate for all audiences. 2023-10-26 20:53:33.135 2023-10-26
#
#   Weekday Type                    Time Time Periods  Likes  ...  \
# 0      Weekend 2023-07-30 06:40:06.356      Morning    908  ...
# 1      Weekend 2022-06-19 14:15:59.833    Afternoon    604  ...
# 2      Weekend 2022-06-04 06:19:50.403      Morning    288  ...
# 3      Weekday 2022-05-12 15:41:21.902    Afternoon    870  ...
# 4      Weekday 2023-10-26 20:53:33.135      Evening    573  ...
#
#    Engagement Rate  Audience Age          Age Group  Audience Gender  \
# 0        91.414554            48      Senior Adults             Male
# 1        45.815296            33      Mature Adults           Female
# 2        22.813990            23  Adolescent Adults            Other
# 3        70.951344            48      Senior Adults             Male
# 4        40.225757            40      Mature Adults             Male
#
#                   Audience Location  Audience Continent Audience Interests  \
# 0                            Greece              Europe         population
# 1  Lao People's Democratic Republic                Asia           attorney
# 2                            Jordan                Asia             affect
# 3                             Sudan              Africa              money
# 4                             Gabon              Africa               part
#
#                             Campaign ID Sentiment Influencer ID
# 0                                   NaN  Positive           NaN
# 1  98705a1e-2573-4cb8-983b-2112d4b140c9  Positive           NaN
# 2                                   NaN   Neutral           NaN
# 3  6b15bf9b-14cc-4ab9-9168-56322057b61e  Positive           NaN
# 4                                   NaN   Neutral           NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\JASH PRAJAPATI\Desktop\My Projecta\Hackathon\Social Media Engagement Report_with_sentiment_vader.xlsx")

# %%
df.head(10)
# Out:
#     Platform                               Post ID Post Type  \
# 0  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 1   Facebook  a30c948b-0fb3-4e92-95da-e2dea184f568      Link
# 2    Twitter  aee74d06-c775-459c-8fc4-013ce25644f1     Image
# 3  Instagram  80415748-a509-4fc6-8b55-74f2babe5dac     Image
# 4   LinkedIn  14d34185-639a-4508-a8b6-02a743fe0dbc      Link
# 5    Twitter  4fb57935-8d9b-4386-ae17-ee955a2e848d      Link
# 6    Twitter  d38fb961-2499-4488-a127-b6624e63f4dd     Image
# 7   Facebook  91c4a56f-b710-4272-9fae-df8932aa8d72     Image
# 8   Facebook  b500076f-b136-4e13-818d-9ef714790f4d     Image
# 9   Facebook  14ca12b7-e129-4cd8-8612-b9ede3064b47      Link
#
#                                  Post Review          Post Timestamp  \
# 0         Loved the creativity in this post. 2023-07-30 06:40:06.356
# 1       Engaging and informative, well done! 2022-06-19 14:15:59.833
# 2                 Just another regular post. 2022-06-04 06:19:50.403
# 3       Not up to the mark, could be better. 2022-05-12 15:41:21.902
# 4         Not appropriate for all audiences. 2023-10-26 20:53:33.135
# 5                      This content is okay. 2024-01-17 15:38:38.798
# 6      Misleading information, disappointed. 2022-07-12 08:53:48.613
# 7  This post is very helpful and insightful. 2021-08-21 05:48:54.000
# 8             Average post, nothing special. 2022-04-12 16:30:04.264
# 9         Not appropriate for all audiences. 2023-07-02 10:57:10.730
#
#         Date Weekday Type                    Time Time Periods  Likes  ...  \
# 0 2023-07-30      Weekend 2023-07-30 06:40:06.356      Morning    908  ...
# 1 2022-06-19      Weekend 2022-06-19 14:15:59.833    Afternoon    604  ...
# 2 2022-06-04      Weekend 2022-06-04 06:19:50.403      Morning    288  ...
# 3 2022-05-12      Weekday 2022-05-12 15:41:21.902    Afternoon    870  ...
# 4 2023-10-26      Weekday 2023-10-26 20:53:33.135      Evening    573  ...
# 5 2024-01-17      Weekday 2024-01-17 15:38:38.798    Afternoon    430  ...
# 6 2022-07-12      Weekday 2022-07-12 08:53:48.613      Morning    973  ...
# 7 2021-08-21      Weekend 2021-08-21 05:48:54.172        Night    137  ...
# 8 2022-04-12      Weekday 2022-04-12 16:30:04.264    Afternoon    658  ...
# 9 2023-07-02      Weekend 2023-07-02 10:57:10.730      Morning    352  ...
#
#    Engagement Rate  Audience Age          Age Group  Audience Gender  \
# 0        91.414554            48      Senior Adults             Male
# 1        45.815296            33      Mature Adults           Female
# 2        22.813990            23  Adolescent Adults            Other
# 3        70.951344            48      Senior Adults             Male
# 4        40.225757            40      Mature Adults             Male
# 5        26.270885            33      Mature Adults            Other
# 6        42.479436            34      Mature Adults           Female
# 7        59.900990            18  Adolescent Adults             Male
# 8        25.230203            47      Senior Adults            Other
# 9        64.902507            47      Senior Adults             Male
#
#                   Audience Location  Audience Continent Audience Interests  \
# 0                            Greece              Europe         population
# 1  Lao People's Democratic Republic                Asia           attorney
# 2                            Jordan                Asia             affect
# 3                             Sudan              Africa              money
# 4                             Gabon              Africa               part
# 5                       Afghanistan                Asia            several
# 6                           Moldova              Europe            husband
# 7                         Hong Kong                Asia              coach
# 8                            Rwanda              Africa           standard
# 9      United States Virgin Islands        NorthAmerica               born
#
#                             Campaign ID Sentiment  \
# 0                                   NaN  Positive
# 1  98705a1e-2573-4cb8-983b-2112d4b140c9  Positive
# 2                                   NaN   Neutral
# 3  6b15bf9b-14cc-4ab9-9168-56322057b61e  Positive
# 4                                   NaN   Neutral
# 5                                   NaN  Positive
# 6                                   NaN  Negative
# 7                                   NaN  Positive
# 8                                   NaN  Negative
# 9                                   NaN   Neutral
#
#                           Influencer ID
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7  020d4653-f752-4176-a694-21b10355604e
# 8                                   NaN
# 9                                   NaN
#
# [10 rows x 24 columns]

# %%
def check_missing_values(dataset):


    """
    Checks for missing values in the dataset and prints the count of missing values per column.

    Parameters:
    dataset (pd.DataFrame): The dataset to check for missing values.
    """
    missing_values = dataset.isna().sum()  # Sum the missing values per column
    print(f'The count of missing values per column:\n{missing_values}')

check_missing_values(df)
# Out:
# The count of missing values per column:
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Review               0
# Post Timestamp            0
# Date                      0
# Weekday Type              0
# Time                      0
# Time Periods              0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Age Group                 0
# Audience Gender           0
# Audience Location         0
# Audience Continent        0
# Audience Interests        0
# Campaign ID           79868
# Sentiment                 0
# Influencer ID         90006
# dtype: int64

# %%
df.columns
# Out:
# Index(['Platform', 'Post ID', 'Post Type', 'Post Review', 'Post Timestamp',
#        'Date', 'Weekday Type', 'Time', 'Time Periods', 'Likes', 'Comments',
#        'Shares', 'Impressions', 'Reach', 'Engagement Rate', 'Audience Age',
#        'Age Group', 'Audience Gender', 'Audience Location',
#        'Audience Continent', 'Audience Interests', 'Campaign ID', 'Sentiment',
#        'Influencer ID'],
#       dtype='object')

# %%
def check_duplicate(dataset):
    """
    Counts the number of duplicate rows in the dataset.

    Parameters:
    dataset (pd.DataFrame): The dataset to check for duplicate rows.

    Returns:
    int: The number of duplicate rows in the dataset.


    """

    duplicate_count=dataset.duplicated().sum()
    return duplicate_count  

duplicate_count=check_duplicate(df)
print(f'There are {duplicate_count} duplicate rows in the dataset.')
# Out:
# There are 0 duplicate rows in the dataset.

# %%
def get_categorical_columns(dataset):
    """
    Retrieves categorical columns from the dataset.

    Parameters:
    dataset (pd.DataFrame): The dataset from which to retrieve categorical columns.

    Returns:
    pd.DataFrame: A DataFrame containing only the categorical columns.

    
    """
    categorical_columns = dataset.select_dtypes(include=['object', 'category'])
    unique_values_cat_cols=categorical_columns.apply(lambda x: x.unique())
    return unique_values_cat_cols
unique_values_count = get_categorical_columns(df)
print(unique_values_count)
# Out:
# Platform                       [Instagram, Facebook, Twitter, LinkedIn]
# Post ID               [16ce29c5-2dc7-478f-9814-a86754f3ce8b, a30c948...
# Post Type                                          [Video, Link, Image]
# Post Review           [Loved the creativity in this post., Engaging ...
# Weekday Type                                         [Weekend, Weekday]
# Time Periods                       [Morning, Afternoon, Evening, Night]
# Age Group             [Senior Adults, Mature Adults, Adolescent Adults]
# Audience Gender                                   [Male, Female, Other]
# Audience Location     [Greece, Lao People's Democratic Republic, Jor...
# Audience Continent    [Europe, Asia, Africa, NorthAmerica, Oceania, ...
# Audience Interests    [population, attorney, affect, money, part, se...
# Campaign ID           [nan, 98705a1e-2573-4cb8-983b-2112d4b140c9, 6b...
# Sentiment                                 [Positive, Neutral, Negative]
# Influencer ID         [nan, 020d4653-f752-4176-a694-21b10355604e, a2...
# dtype: object

# %% [markdown]
# # Data Management

# %%
working_file=df.copy()

# %% [markdown]
# # Understanding the Key Metrics

# %%
engagement_rate=df['Likes']+df['Comments']+df['Shares']/df['Reach']

# %% [markdown]
# # Data Integrity Assurance
# **Recognize that Impressions should outnumber Reach, reflecting total views versus unique audience size.
# Investigate discrepancies between Reach and Impressions to ensure data integrity, identifying and resolving root causes for accurate reporting and analysis.**

# %%
# Count the number of records where Impressions outnumber Reach
outnumber_count = (df['Impressions'] > df['Reach']).sum()

print("Number of records where Impressions outnumber Reach:", outnumber_count)
# Out:
# Number of records where Impressions outnumber Reach: 99992

# %%
# Count the percentage of records which impressions does not outnumber Reach
total_records=len(df)
outnumber_records=(df['Impressions']<= df['Reach']).sum()
percentage_of_records=(outnumber_records/total_records)/100
print('Percentage of records which impressions does not outnumber Reach:',{percentage_of_records})
# Out:
# Percentage of records which impressions does not outnumber Reach: {np.float64(8.000000000000001e-07)}

# %% [markdown]
# # Data Correction
# We get the records in which Impressions outnumber Reach to analyze.We can engage with the concerned team to understand the root cause of discrepancies between Impressions and Reach.

# %%
filtered_df=df[df['Impressions']<df['Reach']]
filtered_df.to_csv('impressions_outnumber_reach.csv', index=False)
print("Filtered records saved to 'impressions_outnumber_reach.csv'")
# Out:
# Filtered records saved to 'impressions_outnumber_reach.csv'

# %% [markdown]
# # Data Enhancement

# %%
bins=[0,30,45,float('inf')]
labels=['Adolescent Adults','Mature Adults','Senior Adults']
df['Age_group']=pd.cut(df['Audience Age'],bins=bins,labels=labels,right=False)
df['Age_group']
# Out:
# 0            Senior Adults
# 1            Mature Adults
# 2        Adolescent Adults
# 3            Senior Adults
# 4            Mature Adults
#                ...
# 99995        Senior Adults
# 99996        Senior Adults
# 99997        Mature Adults
# 99998        Mature Adults
# 99999        Mature Adults
# Name: Age_group, Length: 100000, dtype: category
# Categories (3, object): ['Adolescent Adults' < 'Mature Adults' < 'Senior Adults']

# %% [markdown]
# >which age group are engaged with platforms most?

# %%
# Adjust palette to match number of unique platforms
pastel = sns.color_palette("pastel", n_colors=df['Platform'].nunique())

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Age_group', hue='Platform', palette=pastel)

plt.title('Distribution of Audience Age Group across Platforms')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# >Engagement Rate on Platforms and post types

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Engagement Rate', y='Platform', hue='Post Type', data=df, palette='pastel')


plt.title('Engagement Rate by Platform and Post Type', fontsize=16)
plt.xlabel('Engagement Rate', fontsize=12)
plt.ylabel('Platform', fontsize=12)

plt.show()

# %% [markdown]
# # Temporal Analysis

# %%
def time_date_split(dataset, col):
    """
    Splits the given datetime column into separate date and time columns, 
    and adds month and weekday names.

    Parameters:
    dataset (pd.DataFrame): The DataFrame containing the data.
    col (str): The column name of the datetime field to be split.

    The function adds the following new columns to the dataset:
    - 'Date': The date part extracted from the datetime column.
    - 'Time': The time part, rounded to the nearest hour.
    - 'Month_name': The name of the month.
    - 'Weekday_name': The name of the weekday.
    
    
    """
    dataset['Date'] = pd.to_datetime(dataset[col]).dt.date
    dataset['Time'] = pd.to_datetime(dataset[col]).dt.round('h').dt.time
    dataset['Weekend and Weekday'] = pd.to_datetime(dataset[col]).dt.day_name()
    df['Hour'] = pd.to_datetime(dataset[col]).dt.hour
    df['Year']=pd.to_datetime(dataset[col]).dt.year


time_date_split(df,'Post Timestamp')

# %%
def categorize_time(time):
    
    """
    Categorizes a given time into one of four time periods: Morning, Afternoon, Evening, or Night.
    
    Parameters:
    time (datetime.time): The time to be categorized.
    
    Returns:
    str: The category of the time period ('Morning', 'Afternoon', 'Evening', or 'Night').
    
    Time periods are defined as:
    - Morning: 06:00:00 to 11:59:59
    - Afternoon: 12:00:00 to 16:59:59
    - Evening: 17:00:00 to 20:59:59
    - Night: 21:00:00 to 05:59:59
    """
    if datetime.strptime('06:00:00', '%H:%M:%S').time() <= time < datetime.strptime('12:00:00', '%H:%M:%S').time():
        return 'Morning'
    elif datetime.strptime('12:00:00', '%H:%M:%S').time() <= time < datetime.strptime('17:00:00', '%H:%M:%S').time():
        return 'Afternoon'
    elif datetime.strptime('17:00:00', '%H:%M:%S').time() <= time < datetime.strptime('21:00:00', '%H:%M:%S').time():
        return 'Evening'
    else:
        return 'Night'

df['time_of_day'] = df['Time'].apply(categorize_time)

# %% [markdown]
# >which day of the week,in what hours engagement rate is high

# %%
# Grouping by 'Weekend and Weekday' and 'Hour' to calculate the average engagement rate
day_engagement = df.groupby(['Weekend and Weekday', 'time_of_day'])['Engagement Rate'].mean().reset_index()

# Sorting by 'Engagement Rate' in descending order
day_engagement = day_engagement.sort_values(by='Engagement Rate', ascending=False)

# Display the result
day_engagement
# Out:
#    Weekend and Weekday time_of_day  Engagement Rate
# 1               Friday     Evening        48.080110
# 21             Tuesday     Evening        47.881118
# 4               Monday   Afternoon        47.606766
# 11            Saturday       Night        47.560350
# 16            Thursday   Afternoon        47.497338
# 7               Monday       Night        47.404964
# 6               Monday     Morning        47.236614
# 13              Sunday     Evening        47.197562
# 0               Friday   Afternoon        47.163191
# 24           Wednesday   Afternoon        47.022251
# 18            Thursday     Morning        47.020752
# 20             Tuesday   Afternoon        46.913076
# 19            Thursday       Night        46.888486
# 23             Tuesday       Night        46.882487
# 12              Sunday   Afternoon        46.864940
# 3               Friday       Night        46.829670
# 27           Wednesday       Night        46.828397
# 8             Saturday   Afternoon        46.771797
# 14              Sunday     Morning        46.767816
# 5               Monday     Evening        46.758786
# 26           Wednesday     Morning        46.682566
# 15              Sunday       Night        46.636805
# 22             Tuesday     Morning        46.541642
# 2               Friday     Morning        46.360454
# 17            Thursday     Evening        46.297362
# 10            Saturday     Morning        46.106636
# 25           Wednesday     Evening        45.911414
# 9             Saturday     Evening        45.845017

# %%
# Plotting the line plot
plt.figure(figsize=(12,8))
sns.lineplot(data=df, x='Year', y='Engagement Rate')

# Adding labels and title
plt.title('Engagement Rate by Year')
plt.xlabel('Year')
plt.ylabel('Engagement Rate')

# Show the plot
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
df['Sentiment']=df['Sentiment'].fillna('Mixed Sentiment')

# %%
result = df.groupby('Sentiment')['Engagement Rate'].mean().reset_index().sort_values(by='Engagement Rate', ascending=True)
result
# Out:
#   Sentiment  Engagement Rate
# 1   Neutral        46.301278
# 2  Positive        46.907140
# 0  Negative        47.181271

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=df, 
    x='Sentiment', 
    y='Engagement Rate', 
    hue='Sentiment',       # Explicitly use Sentiment for colors
    palette='pastel', 
    legend=False           # Hide the redundant legend
)
plt.title('Raw Engagement Rate by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Engagement Rate')
plt.tight_layout()
plt.show()
